# %% [markdown]
# ## Módulo 2 - Técnicas de Programação II
#
# ## Projeto Airbnb
#
# New York City Airbnb Open Data
#
# Dupla:  Eden Santana e  Marcus Fontes
#
# Link do KAGGLE | https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data

# %% [markdown]
# ## Divisão de trabalho - Premissas:
#
#  1- Cada pacote precisa de pelo menos 1 gráfico em cada Lib.
#  2- Precisamos diversificar os gráficos para complementar as análises.
#
# **Marcus**
#
#  1- Descrição inicial dos dados com gráficos de barras de algumas variáveis categóricas versus média da variável resposta (PD)
#  2- Histograma de algumas variáveis numéricas (PLT)
#  3- Boxplot para detecção de outliers de algumas variáveis numéricas (PX)
#  4- Scatter com 3 variáveis (cores) para mapear correlações com a variável resposta (SNS)
#
# **Eden**
#
#  1- Gráficos de linhas de variáveis numéricas (médias por categorias no tempo) (PD)
#  2- Gráficos de setores (pizza) com algumas variáveis categóricas (diferentes das já analisadas) (PX)
#  3- Gráficos de barras horizontais com alguma variável dependente versus média da variável resposta (PLT)
#  4- Pairplot e heatmap para análise visual da correlação das variáveis independentes (SNS)

# %% [markdown]
# ### Import dos pacotes necessários

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
## Import dos dados
df = pd.read_csv('./AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Resumo dos dados
#
# Descrição das colunas e sumários

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# **Análise Inicial dos dados - Marcus**

# %%
# 1- Descrição inicial dos dados com gráficos de barras de algumas variáveis categóricas versus média da variável resposta (PD)

# %%
# 2- Histograma de algumas variáveis numéricas (PLT)

# %%
# 3- Boxplot para detecção de outliers de algumas variáveis numéricas (PX)
# Out:
# <div>                            <div id="dce85008-9708-4f8c-b8d8-132972c2e400" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dce85008-9708-4f8c-b8d8-132972c2e400")) {                    Plotly.newPlot(                        "dce85008-9708-4f8c-b8d8-132972c2e400",                        [{"hovertemplate":"Date=%{x}<br>Total=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2019-01-05T00:00:00","2019-03-08T00:00:00","2019-03-03T00:00:00","2019-01-27T00:00:00","2019-02-08T00:00:00","2019-03-25T00:00:00","2019-02-25T00:00:00","2019-02-24T00:00:00","2019-01-10T00:00:00","2019-02-20T00:00:00","2019-02-06T00:00:00","2019-03-09T
# ...

# %%
# 4- Scatter com 3 variáveis (cores) para mapear correlações com a variável resposta (SNS)
# Out:
# <div>                            <div id="6af075c1-b42c-4b63-b6d5-9ed2bdb25740" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6af075c1-b42c-4b63-b6d5-9ed2bdb25740")) {                    Plotly.newPlot(                        "6af075c1-b42c-4b63-b6d5-9ed2bdb25740",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2019-01-01T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-05T00:00:00","2019-01-06T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-12T00:00:0
# ...

# %% [markdown]
# **Análise final dos dados - Eden**

# %%
# 1- Gráficos de linhas de variáveis numéricas (médias por categorias no tempo) (PD)

# %%
# 2- Gráficos de setores (pizza) com algumas variáveis categóricas (diferentes das já analisadas) (PX)

# %%
# 3- Gráficos de barras horizontais com alguma variável dependente versus média da variável resposta (PLT)

# %%
# 4- Pairplot e heatmap para análise visual da correlação das variáveis independentes (SNS)
